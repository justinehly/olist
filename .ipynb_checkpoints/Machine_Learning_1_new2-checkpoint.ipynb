# %% [markdown]
# <a href="https://colab.research.google.com/github/justinehly/olist/blob/main/Machine_Learning_1_new2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Visualization Task: Due May 16

# %% [markdown]
# References:
# * Access to Kaggle dataset on Googledrive:
# * https://towardsdatascience.com/downloading-kaggle-datasets-directly-into-google-colab-c8f0f407d73a
#
# * Accessing zipped folder and merging needed files:
# * https://www.kaggle.com/carolinemnard/customer-segmentation
#
# * EDA:
# My idea

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# Configure a ‘Kaggle Environment’ using OS. This will store the API key and value as an OS environ object/variable. When you run Kaggle terminal commands (in the next step), your machine will be linked to your account through your API token. Linking to the private directory in your Drive ensures that your token information will remain hidden to those you may choose to share notebooks with.

# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')
nb_path = '/content/notebooks'
os.symlink('/content/drive/My Drive/Colab Notebooks', nb_path)
sys.path.insert(0,nb_path)
# Out:
# Mounted at /content/drive

# %%
# !pip install --target=$nb_path kaggle
# Out:
# ...
#      |████████████████████████████████| 61kB 5.6MB/s
# ...
#      |████████████████████████████████| 153kB 22.9MB/s
# ...
#      |████████████████████████████████| 235kB 26.5MB/s
# ...
#      |████████████████████████████████| 61kB 8.6MB/s
# ...
#      |████████████████████████████████| 81kB 10.7MB/s
# ...
#      |████████████████████████████████| 153kB 24.0MB/s
# ...
#      |████████████████████████████████| 184kB 14.0MB/s
# ...
#      |████████████████████████████████| 61kB 8.4MB/s
# ...
#      |████████████████████████████████| 81kB 10.0MB/s
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.12-cp37-none-any.whl size=73053 sha256=020a9d2b533ca9ddae1a65b78e2a8e59d08862ebc78bf2b34f5533db6da308b1
#   Stored in directory: /root/.cache/pip/wheels/a1/6a/26/d30b7499ff85a4a4593377a87ecf55f7d08af42f0de9b60303
# Successfully built kaggle
# ERROR: tensorflow 2.4.1 has requirement six~=1.15.0, but you'll have six 1.16.0 which is incompatible.
# ...

# %%
# Import OS for navigation and environment set up
#import os
# Check current location, '/content' is the Colab virtual machine
#os.getcwd()
# Enable the Kaggle environment, use the path to the directory your Kaggle API JSON is stored in
#os.environ['KAGGLE_CONFIG_DIR'] = '/content/drive/MyDrive/kaggle'

# %% [markdown]
# Install the Kaggle library to enable Kaggle terminal commands (such as downloading data or kernels, see official documentation).

# %%
#!pip install kaggle

# %% [markdown]
# Go to the competition page for your data. Copy the pre-formatted API command from the dataset page you wish to download (for example, this Xray image set).

# %% [markdown]
# Navigate into the directory where you would like to store the data. Paste the API command. Keep the file zipped to save space on your Drive and to import to Colab more efficiently.

# %%
# Navigate into Drive where you want to store your Kaggle data
os.chdir('/content/drive/MyDrive/kaggle')
# Paste and run the copied API command, the data will download to the current directory
# !kaggle datasets download -d olistbr/brazilian-ecommerce


# Check contents of directory, you should see the .zip file for the competition in your Drive
os.listdir()
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 146, in authenticate
#     self.config_file, self.config_dir))
# IOError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.
# ['kaggle.json',
#  'brazilian-ecommerce.zip',
#  'brazil_ecomm_unzipped',
#  'olist_customers_dataset.csv',
#  'olist_order_items_dataset.csv',
#  'olist_geolocation_dataset.csv',
#  'olist_order_payments_dataset.csv',
#  'olist_order_reviews_dataset.csv',
#  'olist_orders_dataset.csv',
#  'olist_products_dataset.csv',
#  'olist_sellers_dataset.csv',
#  'product_category_name_translation.csv']

# %% [markdown]
# When you are ready to use the data in Colab, you will need to copy it from long term storage location on your Drive (‘/gdrive/’) to the temporary virtual machine ('/content') at the start of each session.

# %% [markdown]
# 1. In the project notebook where you will be using the data, mount a connection to Drive as shown above.
# 1. Copy the compressed file to the virtual machine and unzip it to access the data. Do not remove the original zip from your Drive after copying. You will need to copy it at the start of each session while working with Colab.

# %%
# Complete path to storage location of the .zip file of data
zip_path = '../gdrive/content/MyDrive/kaggle/brazilian-ecommerce.zip'
# Check current directory (be sure you're in the directory where Colab operates: '/content')
os.getcwd()
# Copy the .zip file into the present directory
# !cp '{zip_path}' .
# Unzip quietly 
# !unzip -q 'brazilian-ecommerce.zip'

# View the unzipped contents in the virtual machine
os.listdir()
# Out:
# cp: cannot stat '../gdrive/content/MyDrive/kaggle/brazilian-ecommerce.zip': No such file or directory
# replace olist_customers_dataset.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace olist_order_items_dataset.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace olist_order_payments_dataset.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace olist_order_reviews_dataset.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace olist_orders_dataset.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace olist_products_dataset.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace olist_sellers_dataset.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace product_category_name_translation.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# ['kaggle.json',
#  'brazilian-ecommerce.zip',
#  'brazil_ecomm_unzipped',
#  'olist_customers_dataset.csv',
#  'olist_order_items_dataset.csv',
#  'olist_geolocation_dataset.csv',
#  'olist_order_payments_dataset.csv',
# ...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import datetime as dt
#import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
#from shapely.geometry import Polygon, Point, MultiPolygon

# %%
import os
for dirname, _, filenames in os.walk("/content/drive/MyDrive/kaggle"):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/MyDrive/kaggle/kaggle.json
# /content/drive/MyDrive/kaggle/brazilian-ecommerce.zip
# /content/drive/MyDrive/kaggle/olist_customers_dataset.csv
# /content/drive/MyDrive/kaggle/olist_order_items_dataset.csv
# /content/drive/MyDrive/kaggle/olist_geolocation_dataset.csv
# /content/drive/MyDrive/kaggle/olist_order_payments_dataset.csv
# /content/drive/MyDrive/kaggle/olist_order_reviews_dataset.csv
# /content/drive/MyDrive/kaggle/olist_orders_dataset.csv
# /content/drive/MyDrive/kaggle/olist_products_dataset.csv
# /content/drive/MyDrive/kaggle/olist_sellers_dataset.csv
# /content/drive/MyDrive/kaggle/product_category_name_translation.csv
# /content/drive/MyDrive/kaggle/brazil_ecomm_unzipped/olist_customers_dataset.csv
# /content/drive/MyDrive/kaggle/brazil_ecomm_unzipped/olist_geolocation_dataset.csv
# /content/drive/MyDrive/kaggle/brazil_ecomm_unzipped/olist_order_items_dataset.csv
# /content/drive/MyDrive/kaggle/brazil_ecomm_unzipped/olist_order_payments_dataset.csv
# ...

# %%
# !ls
# Out:
# brazil_ecomm_unzipped	       olist_order_payments_dataset.csv
# brazilian-ecommerce.zip        olist_order_reviews_dataset.csv
# kaggle.json		       olist_orders_dataset.csv
# olist_customers_dataset.csv    olist_products_dataset.csv
# olist_geolocation_dataset.csv  olist_sellers_dataset.csv
# olist_order_items_dataset.csv  product_category_name_translation.csv

# %%
root_path = '/content/drive/MyDrive/kaggle/'

customers_df = pd.read_csv(root_path + 'olist_customers_dataset.csv')
items_df = pd.read_csv(root_path + 'olist_order_items_dataset.csv')
payments_df = pd.read_csv(root_path + 'olist_order_payments_dataset.csv')
orders_df = pd.read_csv(root_path + 'olist_orders_dataset.csv')
products_df = pd.read_csv(root_path + 'olist_products_dataset.csv')
sellers_df = pd.read_csv(root_path + 'olist_sellers_dataset.csv')
categories_df = pd.read_csv(root_path + 'product_category_name_translation.csv')

# %%
reviews_df = pd.read_csv(root_path + 'olist_order_reviews_dataset.csv')

# %%
the_df = {'customers': customers_df,
              'items': items_df, 
              'payments': payments_df, 
              'orders': orders_df, 
              'products': products_df, 
              'sellers': sellers_df, 
              'categories': categories_df}
print("_______________________________________________________________________________________________")
print("Description of the {} dataframes".format(len(the_df)))
print("_______________________________________________________________________________________________")
for i, j in the_df.items():
    print('{} dataframe:      {} rows and {} columns'.format(str(i),j.shape[0],j.shape[1]))
    print(list(j.columns))
    print("")
print("________________________________________________________________________________________________")
# Out:
# _______________________________________________________________________________________________
# Description of the 7 dataframes
# _______________________________________________________________________________________________
# customers dataframe:      99441 rows and 5 columns
# ['customer_id', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state']
#
# items dataframe:      112650 rows and 7 columns
# ['order_id', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value']
#
# payments dataframe:      103886 rows and 5 columns
# ['order_id', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value']
#
# orders dataframe:      99441 rows and 8 columns
# ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']
#
# products dataframe:      32951 rows and 9 columns
# ...

# %%
#Merge order dataframe together
df2 = pd.merge(orders_df, customers_df, on='customer_id')
df2 = df2.merge(items_df, on='order_id')
df2 = df2.merge(payments_df, on='order_id')
df2 = df2.merge(sellers_df, on='seller_id')
df2.head(15)
# Out:
#                             order_id  ... seller_state
# 0   e481f51cbdc54678b7cc49136f2d6af7  ...           SP
# 1   e481f51cbdc54678b7cc49136f2d6af7  ...           SP
# 2   e481f51cbdc54678b7cc49136f2d6af7  ...           SP
# 3   8736140c61ea584cb4250074756d8f3b  ...           SP
# 4   a0151737f2f0c6c0a5fd69d45f66ceea  ...           SP
# 5   a3bf941183211246f0d42ad757cba127  ...           SP
# 6   1462290799412b71be32dd880eaf4e1b  ...           SP
# 7   60d13096e69ace88a0c5b8c3805010ca  ...           SP
# 8   e8f1a30189522698bfce82adf60472e7  ...           SP
# 9   a30b65719297f5afcb931bcad170cb7d  ...           SP
# 10  0010b2e5201cc5f1ae7e9c6cc8f5bd00  ...           SP
# 11  44905b3e611d2f738de87a2cca4961b2  ...           SP
# 12  88407c8c6e12493ff6e845df39540112  ...           SP
# 13  e71fb32bec49dd4112bcbcc19126d388  ...           SP
# 14  e71fb32bec49dd4112bcbcc19126d388  ...           SP
#
# [15 rows x 25 columns]

# %%
df3 = df2.merge(reviews_df, on = 'order_id')

# %%
df3.head(10)
# Out:
#                            order_id  ... review_answer_timestamp
# 0  e481f51cbdc54678b7cc49136f2d6af7  ...     2017-10-12 03:43:48
# 1  e481f51cbdc54678b7cc49136f2d6af7  ...     2017-10-12 03:43:48
# 2  e481f51cbdc54678b7cc49136f2d6af7  ...     2017-10-12 03:43:48
# 3  8736140c61ea584cb4250074756d8f3b  ...     2017-08-21 12:43:27
# 4  a0151737f2f0c6c0a5fd69d45f66ceea  ...     2017-07-24 13:59:59
# 5  a3bf941183211246f0d42ad757cba127  ...     2017-08-01 20:06:40
# 6  1462290799412b71be32dd880eaf4e1b  ...     2017-08-31 02:21:39
# 7  60d13096e69ace88a0c5b8c3805010ca  ...     2017-11-19 16:31:28
# 8  e8f1a30189522698bfce82adf60472e7  ...     2017-07-10 11:36:23
# 9  a30b65719297f5afcb931bcad170cb7d  ...     2017-09-08 01:37:01
#
# [10 rows x 31 columns]

# %%
products_df.head(n = 5)
# Out:
#                          product_id  ... product_width_cm
# 0  1e9e8ef04dbcff4541ed26657ea517e5  ...             14.0
# 1  3aa071139cb16b67ca9e5dea641aaa2f  ...             20.0
# 2  96bd76ec8810374ed1b65e291975717f  ...             15.0
# 3  cef67bcfe19066a932b7673e239eb23d  ...             26.0
# 4  9dc1a7de274444849c219cff195d0b71  ...             13.0
#
# [5 rows x 9 columns]

# %%
df3["product_id"].value_counts()
# Out:
# aca2eb7d00ea1a7b8ebd4e68314663af    536
# 99a4788cb24856965c36a24e339b6058    528
# 422879e10f46682990de24d770e7f83d    508
# 389d119b48cf3043d311335e499d9c6b    406
# 368c6c730842d78016ad823897a372db    398
#                                    ...
# 5ffa5bcfb017e836862c86ec3fbf9045      1
# dbedc5c46934d0708dd37cccef1c2184      1
# 7209cdb0efeff5f50f20b2ff4cdd511d      1
# 65aada843fe9bd51339f00c569d7eddc      1
# 6bae58cc7b604c823271ecb0f82de699      1
# Name: product_id, Length: 32951, dtype: int64

# %%
products_df["product_category_name"].value_counts()
# Out:
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: product_category_name, Length: 73, dtype: int64

# %%
products_df["product_id"].value_counts()
# Out:
# acd824083bf35614399164521e080a37    1
# 122ed0b5404fb93c07b3d35c99e8aaa9    1
# 3869f6f786f62c6b885593406506aaab    1
# ba1b78ee2d24870c2bb5c4be33af89eb    1
# 9aa3269c14e72d138d7e346897444d0f    1
#                                    ..
# 98a940d42d3ac029e40441023676ddfe    1
# c01a0404d9e87149110648c7005ce81e    1
# 946b20e2799c73ad1f8f95440f723ce4    1
# cde89c19bf58d71bc836b1495a5ff123    1
# 6bae58cc7b604c823271ecb0f82de699    1
# Name: product_id, Length: 32951, dtype: int64

# %%
prod_cat1 = products_df.copy()[["product_id", "product_category_name"]]
prod_cat1.head()
# Out:
#                          product_id  product_category_name
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas

# %%
#product id for select category
#Category names have many product ids. No product name.
products_df.loc[products_df["product_category_name"] == "perfumaria", "product_id"].value_counts()
# Out:
# c4c273fc9291c33a56ad3f006fe567e4    1
# 94b67faa1e06c405396b019aadf24618    1
# 2044a12ee7346af1ca8f9357bea3fea2    1
# 1b9eb27d35b89e35c8b32fa9902cdba9    1
# a8a2dc008fdc6317702317958b880000    1
#                                    ..
# a2139d605ce44922729e050916c4a667    1
# 5b98dda956628fc9eb2e9c56db3dbcdf    1
# 49e9c574147c521a9bd39ab709a103f3    1
# 61d83b8d80a61b5fd688471b5b273b5f    1
# a035b83b3628decee6e3823924e0c10f    1
# Name: product_id, Length: 868, dtype: int64

# %%
#Add products category
df4_new = df3.copy().merge(prod_cat1, how = 'left')

# %%
df4_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118315 entries, 0 to 118314
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       118315 non-null  object
#  1   customer_id                    118315 non-null  object
#  2   order_status                   118315 non-null  object
#  3   order_purchase_timestamp       118315 non-null  object
#  4   order_approved_at              118300 non-null  object
#  5   order_delivered_carrier_date   117061 non-null  object
#  6   order_delivered_customer_date  115727 non-null  object
#  7   order_estimated_delivery_date  118315 non-null  object
#  8   customer_unique_id             118315 non-null  object
#  9   customer_zip_code_prefix       118315 non-null  int64
#  10  customer_city                  118315 non-null  object
#  11  customer_state                 118315 non-null  object
# ...

# %%
#Which product id have no category name?
#no_cat =df4_new.loc[df4["product_category_name"].isnull()]

# %%
#no_cat.head()

# %%
#testing membership
#All product_id did  not return product_category which means the merge() was accurate.
#cat_test= no_cat.copy().merge(prod_cat1, how = 'left')
#cat_test.info()

# %%
df4_new.head()
# Out:
#                            order_id  ...  product_category_name
# 0  e481f51cbdc54678b7cc49136f2d6af7  ...  utilidades_domesticas
# 1  e481f51cbdc54678b7cc49136f2d6af7  ...  utilidades_domesticas
# 2  e481f51cbdc54678b7cc49136f2d6af7  ...  utilidades_domesticas
# 3  8736140c61ea584cb4250074756d8f3b  ...                  bebes
# 4  a0151737f2f0c6c0a5fd69d45f66ceea  ...             cool_stuff
#
# [5 rows x 32 columns]

# %%
#changing attributes data types
continuous_features = ['payment_value', 'price', 'freight_value']

cat_features = ['order_status', 'customer_city', 'customer_state', 'customer_zip_code_prefix', 'payment_sequential', 
                'payment_installments', 'seller_zip_code_prefix', 'seller_city', 'seller_state', 'review_score',
                'product_category_name']

date_features = ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date',
                 'order_estimated_delivery_date', 'shipping_limit_date', 'review_creation_date', 'review_answer_timestamp']

# %%
# use the "astype" function to change the variable type
df4_new[continuous_features] = df4_new.copy()[continuous_features].astype(np.float64)
df4_new[cat_features] = df4_new.copy()[cat_features].astype("category")


df4_new.info() # now our data looks better!!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118315 entries, 0 to 118314
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       118315 non-null  object
#  1   customer_id                    118315 non-null  object
#  2   order_status                   118315 non-null  category
#  3   order_purchase_timestamp       118315 non-null  object
#  4   order_approved_at              118300 non-null  object
#  5   order_delivered_carrier_date   117061 non-null  object
#  6   order_delivered_customer_date  115727 non-null  object
#  7   order_estimated_delivery_date  118315 non-null  object
#  8   customer_unique_id             118315 non-null  object
#  9   customer_zip_code_prefix       118315 non-null  category
#  10  customer_city                  118315 non-null  category
#  11  customer_state                 118315 non-null  category
# ...

# %%
from datetime import datetime

# %%
#df4['order_approved_at']=pd.to_datetime(df4.copy()['order_approved_at'])

# %%
#worked great
for i in date_features:
    df4_new.loc[:,i] = pd.to_datetime(df4_new.copy().loc[:,i])

# %%
df4_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118315 entries, 0 to 118314
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       118315 non-null  object
#  1   customer_id                    118315 non-null  object
#  2   order_status                   118315 non-null  category
#  3   order_purchase_timestamp       118315 non-null  datetime64[ns]
#  4   order_approved_at              118300 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   117061 non-null  datetime64[ns]
#  6   order_delivered_customer_date  115727 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  118315 non-null  datetime64[ns]
#  8   customer_unique_id             118315 non-null  object
#  9   customer_zip_code_prefix       118315 non-null  category
#  10  customer_city                  118315 non-null  category
# ...

# %%
df4_new.head()
# Out:
#                            order_id  ...  product_category_name
# 0  e481f51cbdc54678b7cc49136f2d6af7  ...  utilidades_domesticas
# 1  e481f51cbdc54678b7cc49136f2d6af7  ...  utilidades_domesticas
# 2  e481f51cbdc54678b7cc49136f2d6af7  ...  utilidades_domesticas
# 3  8736140c61ea584cb4250074756d8f3b  ...                  bebes
# 4  a0151737f2f0c6c0a5fd69d45f66ceea  ...             cool_stuff
#
# [5 rows x 32 columns]

# %%
#date features: day of week and month of order_purchase using purchase timestamp. Further converted to categorical data type.
df4_new['purchase_wk_day'] = df4_new.copy()['order_purchase_timestamp'].dt.day_name().astype('category')
df4_new['purchase_month'] = df4_new.copy()['order_purchase_timestamp'].dt.month_name().astype('category')

# %%
#df4_new.plot.bar(x='purchase_month', y='payment_value')

# %%
import matplotlib.pyplot as plt
#fig = plt.figure()
#ax = fig.add_axes([0,0,1,1])
#ax.bar(df4_new['purchase_month'],df4_new['payment_value'])
#plt.show()

# %%
df4_new['purchase_month'].value_counts()
# Out:
# August       12688
# May          12676
# July         12243
# March        11793
# June         11218
# April        11137
# February     10098
# January       9626
# November      9096
# December      6596
# October       6003
# September     5141
# Name: purchase_month, dtype: int64

# %%
df4_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118315 entries, 0 to 118314
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       118315 non-null  object
#  1   customer_id                    118315 non-null  object
#  2   order_status                   118315 non-null  category
#  3   order_purchase_timestamp       118315 non-null  datetime64[ns]
#  4   order_approved_at              118300 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   117061 non-null  datetime64[ns]
#  6   order_delivered_customer_date  115727 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  118315 non-null  datetime64[ns]
#  8   customer_unique_id             118315 non-null  object
#  9   customer_zip_code_prefix       118315 non-null  category
#  10  customer_city                  118315 non-null  category
# ...

# %%
#Translate Portuguese to English
# !pip install langdetect
# Out:
# ...
#      |████████████████████████████████| 983kB 14.0MB/s
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-cp37-none-any.whl size=993223 sha256=4b546e482d9e77ffa9660fe76c75fb6cb4bd32a5303df0acaf41e25530bfb75e
#   Stored in directory: /root/.cache/pip/wheels/7e/18/13/038c34057808931c7ddc6c92d3aa015cf1a498df5a70268996
# Successfully built langdetect
# ...

# %%
from langdetect import detect

sentence = df3.iloc[1,28]

print(detect(sentence)) # output 'pt' which is portuguese
# Out:
# pt

# %%
# !pip install google_trans_new # Installing the translate API
import google_trans_new # Importing the package
print(google_trans_new.LANGUAGES) # Checking the list of languages that are supported
# Out:
# ...
# {'af': 'afrikaans', 'sq': 'albanian', 'am': 'amharic', 'ar': 'arabic', 'hy': 'armenian', 'az': 'azerbaijani', 'eu': 'basque', 'be': 'belarusian', 'bn': 'bengali', 'bs': 'bosnian', 'bg': 'bulgarian', 'ca': 'catalan', 'ceb': 'cebuano', 'ny': 'chichewa', 'zh-cn': 'chinese (simplified)', 'zh-tw': 'chinese (traditional)', 'co': 'corsican', 'hr': 'croatian', 'cs': 'czech', 'da': 'danish', 'nl': 'dutch', 'en': 'english', 'eo': 'esperanto', 'et': 'estonian', 'tl': 'filipino', 'fi': 'finnish', 'fr': 'french', 'fy': 'frisian', 'gl': 'galician', 'ka': 'georgian', 'de': 'german', 'el': 'greek', 'gu': 'gujarati', 'ht': 'haitian creole', 'ha': 'hausa', 'haw': 'hawaiian', 'iw': 'hebrew', 'he': 'hebrew', 'hi': 'hindi', 'hmn': 'hmong', 'hu': 'hungarian', 'is': 'icelandic', 'ig': 'igbo', 'id': 'indonesian', 'ga': 'irish', 'it': 'italian', 'ja': 'japanese', 'jw': 'javanese', 'kn': 'kannada', 'kk': 'kazakh', 'km': 'khmer', 'ko': 'korean', 'ku': 'kurdish (kurmanji)', 'ky': 'kyrgyz', 'lo': 'lao', 'la': 'l
# ...

# %%
# Running an example of google translate(from portuguese to english), Data Connnection is required.
from google_trans_new import google_translator
translator = google_translator()

# %%
translate_text = translator.translate(sentence, lang_tgt='en',lang_src='pt' )
print(translate_text)
# Out:
# I did not test the product yet, but it came right and in good condition. Only the box that came well kneaded and damaged, which will become annoying, for it is a gift.

# %%
#df4['prod_categ_transl'] = translator.translate(df4.copy()['product_category_name'], lang_tgt='en',lang_src='pt' )

# %%
#transaltions are not tabulated
df4.drop(columns=['prod_categ_transl'], inplace=True)

# %%
df4_trsl = df4_new.copy()

# %%
translations = {}
for column in df_en.columns:
    # unique elements of the column
    unique_elements = df_en[column].unique()
    for element in unique_elements:
        # add translation to the dictionary
        translations[element] = translator.translate(element).text
    
print(translations)
# Out:
#                            order_id  ... purchase_month
# 0  e481f51cbdc54678b7cc49136f2d6af7  ...        October
# 1  e481f51cbdc54678b7cc49136f2d6af7  ...        October
# 2  e481f51cbdc54678b7cc49136f2d6af7  ...        October
# 3  8736140c61ea584cb4250074756d8f3b  ...         August
# 4  a0151737f2f0c6c0a5fd69d45f66ceea  ...           July
#
# [5 rows x 34 columns]

# %%
cat_select = df4_trsl.iloc[:10, 31]

# %%
cat_select
# Out:
# 0    utilidades_domesticas
# 1    utilidades_domesticas
# 2    utilidades_domesticas
# 3                    bebes
# 4               cool_stuff
# 5               cool_stuff
# 6            esporte_lazer
# 7               brinquedos
# 8               cool_stuff
# 9               cool_stuff
# Name: product_category_name, dtype: object

# %%
df4_trsl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118315 entries, 0 to 118314
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       118315 non-null  object
#  1   customer_id                    118315 non-null  object
#  2   order_status                   118315 non-null  category
#  3   order_purchase_timestamp       118315 non-null  datetime64[ns]
#  4   order_approved_at              118300 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   117061 non-null  datetime64[ns]
#  6   order_delivered_customer_date  115727 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  118315 non-null  datetime64[ns]
#  8   customer_unique_id             118315 non-null  object
#  9   customer_zip_code_prefix       118315 non-null  category
#  10  customer_city                  118315 non-null  category
# ...

# %%
#Did not work due to error "429 (Too Many Requests) from TTS API. Probable cause: Unknown"
translations = {}
 # unique elements of the column
unique_elements = df4_trsl.iloc[:,31].unique()
for element in unique_elements:
    # add translation to the dictionary
    translations[element] = translator.translate(element, lang_tgt='en',lang_src='pt').text
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/google_trans_new/google_trans_new.py in translate(self, text, lang_tgt, lang_src, pronounce)
#     188                         raise e
# --> 189             r.raise_for_status()
#     190         except requests.exceptions.ConnectTimeout as e:
#
# /content/notebooks/requests/models.py in raise_for_status(self)
#     942         if http_error_msg:
# --> 943             raise HTTPError(http_error_msg, response=self)
#     944
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://translate.google.cn/_/TranslateWebserverUi/data/batchexecute&q=EgQiWvWKGKWc2oQGIhB6RzHGLrCnc0iwcK7WPDNiMgFy
#
# During handling of the above exception, another exception occurred:
#
# google_new_transError                     Traceback (most recent call last)
# ...

# %%
#try this style for translate
#not worked great
#for i in df4.copy().loc[:,'product_category_name']:
#    df4['prod_categ_transl'] = translator.translate(df4.copy().loc[:, i], lang_tgt='en',lang_src='pt')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'utilidades_domesticas'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-1a21b0c8c114> in <module>()
# ...

# %%
df4_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118315 entries, 0 to 118314
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       118315 non-null  object
#  1   customer_id                    118315 non-null  object
#  2   order_status                   118315 non-null  category
#  3   order_purchase_timestamp       118315 non-null  datetime64[ns]
#  4   order_approved_at              118300 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   117061 non-null  datetime64[ns]
#  6   order_delivered_customer_date  115727 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  118315 non-null  datetime64[ns]
#  8   customer_unique_id             118315 non-null  object
#  9   customer_zip_code_prefix       118315 non-null  category
#  10  customer_city                  118315 non-null  category
# ...

# %% [markdown]
# ## Time series analyses

# %%
#purchase time series
df4_purchase = df4_new[['order_purchase_timestamp', 'payment_value', 'purchase_month']]

# %%
df4_purchase.loc[:,'month_year_purchase'] = df4_purchase.copy().loc[:,'order_purchase_timestamp'].dt.to_period('M')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
df4_purchase_idx = pd.DataFrame(df4_purchase.copy()[['order_purchase_timestamp', 'payment_value', 'purchase_month']], index = df4_purchase['order_purchase_timestamp'])

# %%
df4_purchase.head(n=20)
# Out:
#    order_purchase_timestamp  payment_value purchase_month month_year_purchase
# 0       2017-10-02 10:56:33          18.12        October             2017-10
# 1       2017-10-02 10:56:33           2.00        October             2017-10
# 2       2017-10-02 10:56:33          18.59        October             2017-10
# 3       2017-08-10 13:35:55          83.69         August             2017-08
# 4       2017-07-12 14:11:58          52.77           July             2017-07
# 5       2017-07-24 22:16:25          52.77           July             2017-07
# 6       2017-08-19 14:06:58          44.00         August             2017-08
# 7       2017-11-06 13:48:10          41.01       November             2017-11
# 8       2017-07-05 11:58:33          52.77           July             2017-07
# 9       2017-08-31 17:49:40          62.27         August             2017-08
# 10      2017-09-11 17:39:33          65.50      September             2017-09
# ...

# %%
df4_purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118315 entries, 0 to 118314
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   order_purchase_timestamp  118315 non-null  datetime64[ns]
#  1   payment_value             118315 non-null  float64
#  2   purchase_month            118315 non-null  category
#  3   month_year_purchase       118315 non-null  period[M]
# dtypes: category(1), datetime64[ns](1), float64(1), period[M](1)
# memory usage: 8.7 MB

# %%
df4_purchase['order_purchase_timestamp'].value_counts()
# Out:
# 2017-08-08 20:26:31    63
# 2017-09-23 14:56:45    38
# 2017-04-20 12:45:34    29
# 2017-06-07 12:05:10    26
# 2017-07-07 14:55:43    24
#                        ..
# 2017-02-07 23:53:13     1
# 2017-08-31 22:22:19     1
# 2017-05-03 13:06:02     1
# 2017-05-24 17:19:22     1
# 2018-01-04 15:10:45     1
# Name: order_purchase_timestamp, Length: 98111, dtype: int64

# %%
df4_purchase[df4_purchase.duplicated(keep='last')]
# Out:
#        order_purchase_timestamp  ...  month_year_purchase
# 36          2017-08-24 11:31:28  ...              2017-08
# 62          2018-07-25 10:16:15  ...              2018-07
# 78          2018-05-29 19:12:11  ...              2018-05
# 81          2018-08-25 14:05:07  ...              2018-08
# 83          2018-08-21 10:00:25  ...              2018-08
# ...                         ...  ...                  ...
# 118284      2017-12-18 10:39:37  ...              2017-12
# 118285      2017-12-18 10:39:37  ...              2017-12
# 118289      2018-04-30 10:10:48  ...              2018-04
# 118306      2018-08-10 21:14:35  ...              2018-08
# 118308      2018-03-13 10:58:09  ...              2018-03
#
# [15895 rows x 4 columns]

# %%
df4_purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118315 entries, 0 to 118314
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   order_purchase_timestamp  118315 non-null  datetime64[ns]
#  1   payment_value             118315 non-null  float64
#  2   purchase_month            118315 non-null  category
#  3   month_year_purchase       118315 non-null  period[M]
# dtypes: category(1), datetime64[ns](1), float64(1), period[M](1)
# memory usage: 8.7 MB

# %%
df4_dup.head(n=20)
# Out:
#     order_purchase_timestamp  payment_value purchase_month month_year_purchase
# 37       2017-08-24 11:31:28         127.45         August             2017-08
# 63       2018-07-25 10:16:15         269.97           July             2018-07
# 79       2018-05-29 19:12:11         205.90            May             2018-05
# 82       2018-08-25 14:05:07         265.64         August             2018-08
# 84       2018-08-21 10:00:25         279.30         August             2018-08
# 87       2018-08-20 12:14:50         265.64         August             2018-08
# 90       2018-06-14 14:54:24         173.80           June             2018-06
# 91       2018-06-14 14:54:24         173.80           June             2018-06
# 92       2018-06-14 14:54:24         173.80           June             2018-06
# 94       2018-05-02 06:17:17         273.69            May             2018-05
# 104      2018-07-04 19:41:16         255.44           July             2018-07
# ...

# %%
df4_dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15895 entries, 37 to 118309
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   order_purchase_timestamp  15895 non-null  datetime64[ns]
#  1   payment_value             15895 non-null  float64
#  2   purchase_month            15895 non-null  category
#  3   month_year_purchase       15895 non-null  period[M]
# dtypes: category(1), datetime64[ns](1), float64(1), period[M](1)
# memory usage: 512.6 KB

# %%
#Duplicates:_id may be duplicated up to certain number of columns.
df4_new.head(n=10)
# Out:
#                            order_id  ... purchase_month
# 0  e481f51cbdc54678b7cc49136f2d6af7  ...        October
# 1  e481f51cbdc54678b7cc49136f2d6af7  ...        October
# 2  e481f51cbdc54678b7cc49136f2d6af7  ...        October
# 3  8736140c61ea584cb4250074756d8f3b  ...         August
# 4  a0151737f2f0c6c0a5fd69d45f66ceea  ...           July
# 5  a3bf941183211246f0d42ad757cba127  ...           July
# 6  1462290799412b71be32dd880eaf4e1b  ...         August
# 7  60d13096e69ace88a0c5b8c3805010ca  ...       November
# 8  e8f1a30189522698bfce82adf60472e7  ...           July
# 9  a30b65719297f5afcb931bcad170cb7d  ...         August
#
# [10 rows x 34 columns]

# %%
df4_new["cust_deliv_estimat"] = (df4_new.copy()["order_estimated_delivery_date"]-df4_new.copy()["order_delivered_customer_date"])

# %%
#Convert the duration to days
df4_new["cust_deliv_estimat-days"] = df4_new.copy()["cust_deliv_estimat"].dt.days

# %%
df4_new.head(n=15)
# Out:
#                             order_id  ... cust_deliv_estimat-days
# 0   e481f51cbdc54678b7cc49136f2d6af7  ...                     7.0
# 1   e481f51cbdc54678b7cc49136f2d6af7  ...                     7.0
# 2   e481f51cbdc54678b7cc49136f2d6af7  ...                     7.0
# 3   8736140c61ea584cb4250074756d8f3b  ...                     6.0
# 4   a0151737f2f0c6c0a5fd69d45f66ceea  ...                     6.0
# 5   a3bf941183211246f0d42ad757cba127  ...                     6.0
# 6   1462290799412b71be32dd880eaf4e1b  ...                    16.0
# 7   60d13096e69ace88a0c5b8c3805010ca  ...                     9.0
# 8   e8f1a30189522698bfce82adf60472e7  ...                    10.0
# 9   a30b65719297f5afcb931bcad170cb7d  ...                    12.0
# 10  0010b2e5201cc5f1ae7e9c6cc8f5bd00  ...                     3.0
# 11  44905b3e611d2f738de87a2cca4961b2  ...                    14.0
# 12  88407c8c6e12493ff6e845df39540112  ...                     2.0
# ...

# %%
#check point to directory
df4_new.to_csv('/content/drive/MyDrive/Colab Notebooks/olist_df_select.csv')

# %%
df4_new.tail(n= 20)
# Out:
#                                 order_id  ... cust_deliv_estimat-days
# 118295  1449769412dea5d16183085a97ba3bca  ...                     NaN
# 118296  8505d7267ce3f58c129ffa8468cebf21  ...                     NaN
# 118297  a9411a80b515013f1cd3c7ca3d585433  ...                    15.0
# 118298  a6c258c89be1621b6e7c2bd85b4c866d  ...                     2.0
# 118299  80ba449ea98f8e879a829759b5a66294  ...                    14.0
# 118300  8c1d27c10cc60cc369a428813bb71350  ...                    13.0
# 118301  39e89b39b5cc8b5e3a38f23e915d1823  ...                    12.0
# 118302  b1866dace5f7daf46e4ef10ed7c3a5e9  ...                   -10.0
# 118303  fbff77db5421bb7e1da292db45d07e75  ...                    13.0
# 118304  fbff77db5421bb7e1da292db45d07e75  ...                    13.0
# 118305  f5f8998eee8ec7bc513dc52847d64ce0  ...                     NaN
# 118306  5bacbd9f42bd029c3a296501224e193e  ...                     8.0
# ...

# %%
#df4_purchase[['month_year_purchase']].plot()
plt.plot(df4_purchase['month_year_purchase'], df4_purchase['payment_value'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-135-d35f9b4baee9> in <module>()
#       1 #df4_purchase[['month_year_purchase']].plot()
# ----> 2 plt.plot(df4_purchase['month_year_purchase'], df4_purchase['payment_value'])
#       3 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
# ...

# %%
list(df3[1, 2, 3].dtypes())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (1, 2, 3)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-147-ad8c6f42634c> in <module>()
# ...

# %%
df4[prod_categ_transl] = translator.translate(df4.copy()[''], lang_tgt='en',lang_src='pt' )
